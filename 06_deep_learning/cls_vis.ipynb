# %%
# -*- coding: utf-8 -*-
"""
@author:XuMing(xuming624@qq.com)
@description: 
"""
import sys

sys.path.append('..')
from pytextclassifier import TextClassifier
import numpy as np

from sklearn import metrics


class CharTokenizer:
    def tokenize(self, text):
        """Tokenizes a piece of text."""
        # Char seg Chinese
        return list(text.lower())


m = TextClassifier(model_name='lr')
# model_name 是选择分类器，支持lr, random_forest, xgboost, svm, mlp, ensemble, stack
data = [
    ('education', '名师指导托福语法技巧：名词的复数形式'),
    ('education', '中国高考成绩海外认可 是“狼来了”吗？'),
    ('sports', '图文：法网孟菲尔斯苦战进16强 孟菲尔斯怒吼'),
    ('sports', '四川丹棱举行全国长距登山挑战赛 近万人参与'),
    ('sports', '米兰客场8战不败国米10年连胜')
]
m.train(data, token_pattern=r"\S+")  # 匹配任何非空白字符

r = m.predict(['福建春季公务员考试报名18日截止 2月6日考试',
               '意甲首轮补赛交战记录:米兰客场8战不败国米10年连胜'])
print(r)
m.save()
#del m

new_m = TextClassifier(model_name='lr')
new_m.load()
predict_label_prob = new_m.predict_proba(['福建春季公务员考试报名18日截止 2月6日考试'])
print(predict_label_prob)  # [[0.53337174 0.46662826]]
print('classes_: ', new_m.model.classes_)  # the classes ordered as prob
print('sport prob: ', predict_label_prob[0][np.where(np.array(new_m.model.classes_) == 'sports')])

predict_label = new_m.predict(['福建春季公务员考试报名18日截止 2月6日考试',
                               '意甲首轮补赛交战记录:米兰客场8战不败国米10年连胜'])
print(predict_label)  # ['education', 'sports']

test_data = [
    ('education', '福建春季公务员考试报名18日截止 2月6日考试'),
    ('sports', '意甲首轮补赛交战记录:米兰客场8战不败国米10年连胜'),
]
acc_score = new_m.test(test_data)
print(acc_score)  # 1.0
# Out:
# [  DEBUG 20210903 11:57:45 textclassifier:  74] train model
# [  DEBUG 20210903 11:57:45 textclassifier:  60] load data_list, X size: 5, label size: 5
# [  DEBUG 20210903 11:57:45 textclassifier:  62] num_classes:2
# [  DEBUG 20210903 11:57:45 textclassifier:  65] data tokens top 3: ['名师 指导 托福 语法 技巧 ： 名词 的 复数 形式', '中国 高考 成绩 海外 认可 是 “ 狼来了 ” 吗 ？', '图文 ： 法网 孟菲尔 斯 苦战 进 16 强 孟菲尔 斯 怒吼']
# [   INFO 20210903 11:57:45 data_utils: 183] save classifier_vectorizer.pkl ok.
# [   INFO 20210903 11:57:45 data_utils: 183] save classifier_model.pkl ok.
# [   INFO 20210903 11:57:45 textclassifier: 147] save done. vec path: classifier_vectorizer.pkl, model path: classifier_model.pkl
# [   INFO 20210903 11:57:45 textclassifier: 161] model loaded from
# [  DEBUG 20210903 11:57:45 textclassifier:  92] test model
# [  DEBUG 20210903 11:57:45 textclassifier:  60] load data_list, X size: 2, label size: 2
# [  DEBUG 20210903 11:57:45 textclassifier:  62] num_classes:2
# [  DEBUG 20210903 11:57:45 textclassifier:  65] data tokens top 3: ['福建 春季 公务员 考试 报名 18 日 截止 2 月 6 日 考试', '意甲 首轮 补赛 交战 记录 : 米兰 客场 8 战 不败 国米 10 年 连胜']
# ['education' 'sports']
# [[0.5 0.5]]
# classes_:  ['education' 'sports']
# sport prob:  [0.5]
# ['education' 'sports']
# classify_report :
#                precision    recall  f1-score   support
#
#    education       1.00      1.00      1.00         1
#       sports       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# confusion_matrix :
#  [[1 0]
#  [0 1]]
# acc_for_each_class :
#  [1. 1.]
# average_accuracy: 1.0000
# overall_accuracy: 1.0000
# accuracy_score: 1.0000
# 1.0

# %%
from eli5 import show_weights
show_weights(new_m.model, vec=new_m.vectorizer)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sports
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.136
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         孟菲尔
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.136
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         孟菲尔 斯
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.136
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         斯
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         四川
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         举行
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         举行 全国
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         全国
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         全国 长距
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         国米
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         挑战赛 近万人
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         挑战赛
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         登山
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         战
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         四川 丹棱
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         客场
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         战 不败
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         年
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         丹棱
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         丹棱 举行
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         10
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 33 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 40 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>

# %%
from eli5 import show_prediction
valid_xs = ['福建春季公务员考试报名18日截止 2月6日考试',
                               '意甲首轮补赛交战记录:米兰客场8战不败国米10年连胜']
show_prediction(new_m.model, valid_xs[0], vec=new_m.vectorizer, 
                show_feature_values=True, top=10,target_names=['sports','educ'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">福建春季公务员考试报名18日截止 2月6日考试</span>
#     </p>

# %%
from sklearn.datasets import fetch_20newsgroups

categories = ['alt.atheism', 'soc.religion.christian',
              'comp.graphics', 'sci.med']
twenty_train = fetch_20newsgroups(
    subset='train',
    categories=categories,
    shuffle=True,
    random_state=42
)
twenty_test = fetch_20newsgroups(
    subset='test',
    categories=categories,
    shuffle=True,
    random_state=42
)

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegressionCV
from sklearn.pipeline import make_pipeline

vec = CountVectorizer()
clf = LogisticRegressionCV()
pipe = make_pipeline(vec, clf)
pipe.fit(twenty_train.data, twenty_train.target)

from sklearn import metrics

def print_report(pipe):
    y_test = twenty_test.target
    y_pred = pipe.predict(twenty_test.data)
    report = metrics.classification_report(y_test, y_pred,
        target_names=twenty_test.target_names)
    print(report)
    print("accuracy: {:0.3f}".format(metrics.accuracy_score(y_test, y_pred)))

print_report(pipe)
# Out:
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                         precision    recall  f1-score   support
#
#            alt.atheism       0.91      0.81      0.85       319
#          comp.graphics       0.86      0.94      0.90       389
#                sci.med       0.92      0.81      0.86       396
# soc.religion.christian       0.88      0.98      0.92       398
#
#               accuracy                           0.89      1502
#              macro avg       0.89      0.89      0.89      1502
#           weighted avg       0.89      0.89      0.89      1502
#
# accuracy: 0.889

# %%
import eli5
eli5.show_weights(clf, top=10)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=3
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.709
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x199378
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.601
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x938889
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.820
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x349126
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.691
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x718537
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.562
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x242643
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.522
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x71928
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 88.90%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 53649 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 88.04%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 53981 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 88.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.694
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x683213
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.757
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x741207
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.874
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x199709
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.982
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x641063
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#                         </td>
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.530
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x580586
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.848
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x342790
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.747
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x771885
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.93%); border: none;">
#     <td style="padding

# %%
eli5.show_weights(clf, vec=vec, top=10,
                  target_names=twenty_test.target_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=alt.atheism
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=comp.graphics
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=sci.med
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=soc.religion.christian
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.709
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x199378
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.601
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x938889
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.820
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x349126
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.691
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x718537
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.562
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x242643
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.522
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x71928
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 88.90%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 53649 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 88.04%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 53981 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 88.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.694
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x683213
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.757
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x741207
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.874
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x199709
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.982
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x641063
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#                         </td>
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.530
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x580586
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.848
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x342790
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.747
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x771885
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%

# %%
twenty_test.target_names
# Out:
# ['alt.atheism', 'comp.graphics', 'sci.med', 'soc.religion.christian']

# %%
twenty_test.data[0]
# Out:
# "As I recall from my bout with kidney stones, there isn't any\nmedication that can do anything about them except relieve the pain.\n\nEither they pass, or they have to be broken up with sound, or they have\nto be extracted surgically.\n\nWhen I was in, the X-ray tech happened to mention that she'd had kidney\nstones and children, and the childbirth hurt less."

# %%
eli5.show_prediction(clf, twenty_test.data[0], vec=vec,
                     target_names=twenty_test.target_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (score <b>-0.935</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.025
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.960
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as i </span><span style="background-color: hsl(0, 100.00%, 92.17%); opacity: 0.82" title="-0.024">recall</span><span style="opacity: 0.80"> from my </span><span style="background-color: hsl(120, 100.00%, 96.57%); opacity: 0.81" title="0.007">bout</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(0, 100.00%, 94.42%); opacity: 0.81" title="-0.015">kidney</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.68%); opacity: 0.80" title="-0.002">stones</span><span style="opacity: 0.80">, there </span><span style="background-color: hsl(120, 100.00%, 73.60%); opacity: 0.91" title="0.137">isn</span><span style="opacity: 0.80">&#x27;t any
# </span><span style="background-color: hsl(0, 100.00%, 95.78%); opacity: 0.81" title="-0.010">medication</span><span style="opacity: 0.80"> that can do anything about them except relieve the </span><span style="background-color: hsl(0, 100.00%, 88.08%); opacity: 0.84" title="-0.044">pain</span><span style="opacity: 0.80">.
#
# either they </span><span style="background-color: hsl(120, 100.00%, 95.10%); opacity: 0.81" title="0.012">pass</span><span style="opacity: 0.80">, or they have to be </span><span style="background-color: hsl(0, 100.00%, 88.88%); opacity: 0.83" title="-0.040">broken</span><span style="opacity: 0.80"> up with </span><span style="background-color: hsl(0, 100.00%, 93.79%); opacity: 0.81" title="-0.017">sound</span><span style="opacity: 0.80">, or they have
# to be </span><span style="background-color: hsl(0, 100.00%, 94.81%); opacity: 0.81" title="-0.013">extracted</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.33%); opacity: 0.80" title="-0.003">surgically</span><span style="opacity: 0.80">.
#
# when i was in, the x-</span><span style="background-color: hsl(120, 100.00%, 97.97%); opacity: 0.80" title="0.004">ray</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.34%); opacity: 0.83" title="-0.033">tech</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.52%); opacity: 0.81" title="0.014">happened</span><span style="opacity: 0.80"> to </span><span style="background-color: hsl(120, 100.00%, 83.95%); opacity: 0.85" title="0.067">mention</span><span style="opacity: 0.80"> that she&#x27;d had </span><span style="background-color: hsl(0, 100.00%, 94.42%); opacity: 0.81" title="-0.015">kidney</span><span style="opacity: 0.80">
# </span><span style="background-color: hsl(0, 100.00%, 98.68%); opacity: 0.80" title="-0.002">stones</span><span style="opacity: 0.80"> and </span><span style="background-color: hsl(120, 100.00%, 93.07%); opacity: 0.82" title="0.020">children</span><span style="opacity: 0.80">, and the </span><span style="background-color: hsl(0, 100.00%, 97.75%); opacity: 0.80" title="-0.004">childbirth</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.08%); opacity: 0.82" title="-0.029">hurt</span><span style="opacity: 0.80"> less.</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=comp.graphics
#
# </b>
#
#
#     (score <b>-0.705</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 91.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.271
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.435
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as i </span><span style="background-color: hsl(0, 100.00%, 91.13%); opacity: 0.82" title="-0.029">recall</span><span style="opacity: 0.80"> from my </span><span style="background-color: hsl(0, 100.00%, 99.19%); opacity: 0.80" title="-0.001">bout</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(0, 100.00%, 91.52%); opacity: 0.82" title="-0.027">kidney</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.07%); opacity: 0.82" title="-0.025">stones</span><span style="opacity: 0.80">, there </span><span style="background-color: hsl(0, 100.00%, 89.80%); opacity: 0.83" title="-0.035">isn</span><span style="opacity: 0.80">&#x27;t any
# </span><span style="background-color: hsl(0, 100.00%, 86.36%); opacity: 0.84" title="-0.053">medication</span><span style="opacity: 0.80"> that can do anything about them except </span><span style="background-color: hsl(0, 100.00%, 97.64%); opacity: 0.80" title="-0.004">relieve</span><span style="opacity: 0.80"> the </span><span style="

# %%
eli5.show_prediction(clf, twenty_test.data[0], vec=vec,
                     target_names=twenty_test.target_names,
                     targets=['sci.med'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sci.med
#
# </b>
#
#
#     (score <b>0.225</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.783
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.558
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as i </span><span style="background-color: hsl(120, 100.00%, 78.35%); opacity: 0.88" title="0.103">recall</span><span style="opacity: 0.80"> from my </span><span style="background-color: hsl(120, 100.00%, 98.81%); opacity: 0.80" title="0.002">bout</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(120, 100.00%, 79.45%); opacity: 0.88" title="0.096">kidney</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.99%); opacity: 0.83" title="0.034">stones</span><span style="opacity: 0.80">, there </span><span style="background-color: hsl(0, 100.00%, 90.14%); opacity: 0.83" title="-0.033">isn</span><span style="opacity: 0.80">&#x27;t any
# </span><span style="background-color: hsl(120, 100.00%, 74.66%); opacity: 0.90" title="0.129">medication</span><span style="opacity: 0.80"> that can do anything about them except </span><span style="background-color: hsl(120, 100.00%, 98.25%); opacity: 0.80" title="0.003">relieve</span><span style="opacity: 0.80"> the </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.248">pain</span><span style="opacity: 0.80">.
#
# either they </span><span style="background-color: hsl(0, 100.00%, 91.12%); opacity: 0.82" title="-0.029">pass</span><span style="opacity: 0.80">, or they have to be </span><span style="background-color: hsl(120, 100.00%, 93.99%); opacity: 0.81" title="0.017">broken</span><span style="opacity: 0.80"> up with </span><span style="background-color: hsl(120, 100.00%, 78.45%); opacity: 0.88" title="0.102">sound</span><span style="opacity: 0.80">, or they have
# to be extracted </span><span style="background-color: hsl(120, 100.00%, 95.46%); opacity: 0.81" title="0.011">surgically</span><span style="opacity: 0.80">.
#
# when i was in, the x-</span><span style="background-color: hsl(0, 100.00%, 88.24%); opacity: 0.83" title="-0.043">ray</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.62%); opacity: 0.83" title="0.036">tech</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.41%); opacity: 0.82" title="0.019">happened</span><span style="opacity: 0.80"> to </span><span style="background-color: hsl(0, 100.00%, 94.83%); opacity: 0.81" title="-0.013">mention</span><span style="opacity: 0.80"> that she&#x27;d had </span><span style="background-color: hsl(120, 100.00%, 79.45%); opacity: 0.88" title="0.096">kidney</span><span style="opacity: 0.80">
# </span><span style="background-color: hsl(120, 100.00%, 89.99%); opacity: 0.83" title="0.034">stones</span><span style="opacity: 0.80"> and </span><span style="background-color: hsl(0, 100.00%, 91.78%); opacity: 0.82" title="-0.026">children</span><span style="opacity: 0.80">, and the </span><span style="background-color: hsl(120, 100.00%, 96.92%); opacity: 0.81" title="0.006">childbirth</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.82%); opacity: 0.81" title="0.017">hurt</span><span style="opacity: 0.80"> less.</span>
#     </p>

# %%
vec = CountVectorizer(stop_words='english')
clf = LogisticRegressionCV()
pipe = make_pipeline(vec, clf)
pipe.fit(twenty_train.data, twenty_train.target)

print_report(pipe)
# Out:
#                         precision    recall  f1-score   support
#
#            alt.atheism       0.86      0.76      0.81       319
#          comp.graphics       0.85      0.94      0.89       389
#                sci.med       0.92      0.85      0.88       396
# soc.religion.christian       0.86      0.89      0.87       398
#
#               accuracy                           0.87      1502
#              macro avg       0.87      0.86      0.86      1502
#           weighted avg       0.87      0.87      0.87      1502
#
# accuracy: 0.868

# %%
eli5.show_prediction(clf, twenty_test.data[0], vec=vec,
                     target_names=twenty_test.target_names,
                     targets=['sci.med'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sci.med
#
# </b>
#
#
#     (probability <b>0.603</b>, score <b>1.212</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.035
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.176
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as i </span><span style="background-color: hsl(120, 100.00%, 72.36%); opacity: 0.92" title="0.176">recall</span><span style="opacity: 0.80"> from my </span><span style="background-color: hsl(0, 100.00%, 99.77%); opacity: 0.80" title="-0.000">bout</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(120, 100.00%, 80.74%); opacity: 0.87" title="0.105">kidney</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.17%); opacity: 0.83" title="0.046">stones</span><span style="opacity: 0.80">, there </span><span style="background-color: hsl(0, 100.00%, 82.30%); opacity: 0.86" title="-0.093">isn</span><span style="opacity: 0.80">&#x27;t any
# </span><span style="background-color: hsl(120, 100.00%, 68.51%); opacity: 0.94" title="0.212">medication</span><span style="opacity: 0.80"> that can do anything about them except </span><span style="background-color: hsl(120, 100.00%, 98.08%); opacity: 0.80" title="0.004">relieve</span><span style="opacity: 0.80"> the </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.298">pain</span><span style="opacity: 0.80">.
#
# either they </span><span style="background-color: hsl(0, 100.00%, 90.03%); opacity: 0.83" title="-0.041">pass</span><span style="opacity: 0.80">, or they have to be </span><span style="background-color: hsl(0, 100.00%, 93.25%); opacity: 0.82" title="-0.023">broken</span><span style="opacity: 0.80"> up with </span><span style="background-color: hsl(120, 100.00%, 69.10%); opacity: 0.94" title="0.206">sound</span><span style="opacity: 0.80">, or they have
# to be </span><span style="background-color: hsl(120, 100.00%, 97.39%); opacity: 0.80" title="0.006">extracted</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.30%); opacity: 0.81" title="0.014">surgically</span><span style="opacity: 0.80">.
#
# when i was in, the x-</span><span style="background-color: hsl(0, 100.00%, 81.90%); opacity: 0.86" title="-0.096">ray</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.30%); opacity: 0.82" title="0.034">tech</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.81%); opacity: 0.84" title="0.055">happened</span><span style="opacity: 0.80"> to </span><span style="background-color: hsl(0, 100.00%, 92.74%); opacity: 0.82" title="-0.026">mention</span><span style="opacity: 0.80"> that she&#x27;d had </span><span style="background-color: hsl(120, 100.00%, 80.74%); opacity: 0.87" title="0.105">kidney</span><span style="opacity: 0.80">
# </span><span style="background-color: hsl(120, 100.00%, 89.17%); opacity: 0.83" title="0.046">stones</span><span style="opacity: 0.80"> and </span><span style="background-color: hsl(0, 100.00%, 95.09%); opacity: 0.81" title="-0.015">children</span><span style="opacity: 0.80">, and the </span><span style="background-color: hsl(120, 100.00%, 97.89%); opacity: 0.80" title="0.004">childbirth</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.03%); opacity: 0.81" title="0.020">hurt</span><span style="opacity: 0.80"> less.</span>
#     </p>

# %% [markdown]
# # 4. Char-based pipeline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vec = TfidfVectorizer(stop_words='english', analyzer='char',
                      ngram_range=(3,5))
clf = LogisticRegressionCV()
pipe = make_pipeline(vec, clf)
len(twenty_train.data)
# Out:
# 2257

# %%
twenty_train.data = twenty_train.data[:20]
twenty_train.target = twenty_train.target[:20]
len(twenty_train.data)
# Out:
# 20

# %%
pipe.fit(twenty_train.data, twenty_train.target)

print_report(pipe)
# Out:
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
#                         precision    recall  f1-score   support
#
#            alt.atheism       0.94      0.05      0.10       319
#          comp.graphics       0.80      0.15      0.25       389
#                sci.med       0.25      0.10      0.14       396
# soc.religion.christian       0.30      0.94      0.45       398
#
#               accuracy                           0.32      1502
#              macro avg       0.57      0.31      0.23      1502
#           weighted avg       0.55      0.32      0.24      1502
#
# accuracy: 0.323

# %%
eli5.show_prediction(clf, twenty_test.data[0], vec=vec,
                     target_names=twenty_test.target_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.153</b>, score <b>-0.411</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.205
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.206
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 97.74%); opacity: 0.80" title="0.000">f</span><span style="background-color: hsl(120, 100.00%, 96.70%); opacity: 0.81" title="0.000">r</span><span style="background-color: hsl(120, 100.00%, 96.12%); opacity: 0.81" title="0.000">o</span><span style="background-color: hsl(120, 100.00%, 96.48%); opacity: 0.81" title="0.000">m</span><span style="background-color: hsl(120, 100.00%, 97.72%); opacity: 0.80" title="0.000">:</span><span style="background-color: hsl(0, 100.00%, 96.06%); opacity: 0.81" title="-0.000"> </span><span style="background-color: hsl(0, 100.00%, 92.39%); opacity: 0.82" title="-0.001">b</span><span style="background-color: hsl(0, 100.00%, 91.61%); opacity: 0.82" title="-0.001">r</span><span style="background-color: hsl(0, 100.00%, 90.19%); opacity: 0.83" title="-0.002">i</span><span style="background-color: hsl(0, 100.00%, 92.35%); opacity: 0.82" title="-0.001">a</span><span style="background-color: hsl(0, 100.00%, 92.41%); opacity: 0.82" title="-0.001">n</span><span style="background-color: hsl(0, 100.00%, 94.52%); opacity: 0.81" title="-0.001">@</span><span style="background-color: hsl(0, 100.00%, 95.91%); opacity: 0.81" title="-0.000">u</span><span style="background-color: hsl(0, 100.00%, 94.26%); opacity: 0.81" title="-0.001">c</span><span style="background-color: hsl(0, 100.00%, 93.09%); opacity: 0.82" title="-0.001">s</span><span style="background-color: hsl(0, 100.00%, 88.90%); opacity: 0.83" title="-0.002">d</span><span style="background-color: hsl(0, 100.00%, 90.44%); opacity: 0.83" title="-0.002">.</span><span style="background-color: hsl(0, 100.00%, 91.09%); opacity: 0.82" title="-0.001">e</span><span style="background-color: hsl(0, 100.00%, 92.25%); opacity: 0.82" title="-0.001">d</span><span style="background-color: hsl(0, 100.00%, 93.41%); op
.50%); opacity: 0.82" title="0.001">f</span><span style="background-color: hsl(120, 100.00%, 91.63%); opacity: 0.82" title="0.001">o</span><span style="background-color: hsl(120, 100.00%, 92.68%); opacity: 0.82" title="0.001">r</span><span style="background-color: hsl(120, 100.00%, 92.36%); opacity: 0.82" title="0.001"> </span><span style="background-color: hsl(120, 100.00%, 92.87%); opacity: 0.82" title="0.001">k</span><span style="background-color: hsl(120, 100.00%, 92.90%); opacity: 0.82" title="0.001">i</span><span style="background-color: hsl(120, 100.00%, 94.18%); opacity: 0.81" title="0.001">d</span><span style="background-color: hsl(0, 100.00%, 97.52%); opacity: 0.80" title="-0.000">n</span><span style="background-color: hsl(0, 100.00%, 96.26%); opacity: 0.81" title="-0.000">e</span><span style="background-color: hsl(0,

# %%
vec = TfidfVectorizer(analyzer='char_wb', ngram_range=(3,5))
clf = LogisticRegressionCV()
pipe = make_pipeline(vec, clf)
pipe.fit(twenty_train.data, twenty_train.target)

print_report(pipe)
# Out:
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
#                         precision    recall  f1-score   support
#
#            alt.atheism       0.86      0.06      0.11       319
#          comp.graphics       0.77      0.21      0.33       389
#                sci.med       0.28      0.11      0.16       396
# soc.religion.christian       0.30      0.93      0.46       398
#
#               accuracy                           0.34      1502
#              macro avg       0.55      0.33      0.26      1502
#           weighted avg       0.54      0.34      0.27      1502
#
# accuracy: 0.342

# %%
eli5.show_prediction(clf, twenty_test.data[0], vec=vec,
                     target_names=twenty_test.target_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.149</b>, score <b>-0.441</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.206
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.235
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 92.97%); opacity: 0.82" title="0.001">f</span><span style="background-color: hsl(120, 100.00%, 91.82%); opacity: 0.82" title="0.001">r</span><span style="background-color: hsl(120, 100.00%, 92.96%); opacity: 0.82" title="0.001">o</span><span style="background-color: hsl(120, 100.00%, 94.21%); opacity: 0.81" title="0.001">m</span><span style="background-color: hsl(120, 100.00%, 96.28%); opacity: 0.81" title="0.000">:</span><span style="background-color: hsl(0, 100.00%, 94.91%); opacity: 0.81" title="-0.001"> </span><span style="background-color: hsl(0, 100.00%, 89.80%); opacity: 0.83" title="-0.001">b</span><span style="background-color: hsl(0, 100.00%, 88.56%); opacity: 0.83" title="-0.002">r</span><span style="background-color: hsl(0, 100.00%, 86.56%); opacity: 0.84" title="-0.002">i</span><span style="background-color: hsl(0, 100.00%, 89.51%); opacity: 0.83" title="-0.002">a</span><span style="background-color: hsl(0, 100.00%, 89.52%); opacity: 0.83" title="-0.002">n</span><span style="background-color: hsl(0, 100.00%, 92.43%); opacity: 0.82" title="-0.001">@</span><span style="background-color: hsl(0, 100.00%, 93.90%); opacity: 0.81" title="-0.001">u</span><span style="background-color: hsl(0, 100.00%, 91.60%); opacity: 0.82" title="-0.001">c</span><span style="background-color: hsl(0, 100.00%, 89.95%); opacity: 0.83" title="-0.001">s</span><span style="background-color: hsl(0, 100.00%, 84.69%); opacity: 0.85" title="-0.003">d</span><span style="background-color: hsl(0, 100.00%, 87.44%); opacity: 0.84" title="-0.002">.</span><span style="background-color: hsl(0, 100.00%, 89.81%); opacity: 0.83" title="-
0.003">p</span><span style="background-color: hsl(0, 100.00%, 95.31%); opacity: 0.81" title="-0.000"> </span><span style="background-color: hsl(120, 100.00%, 89.64%); opacity: 0.83" title="0.002">f</span><span style="background-color: hsl(120, 100.00%, 89.16%); opacity: 0.83" title="0.002">o</span><span style="background-color: hsl(120, 100.00%, 90.62%); opacity: 0.83" title="0.001">r</span><span style="background-color: hsl(120, 100.00%, 89.47%); opacity: 0.83" title="0.002"> </span><span style="background-color: hsl(120, 100.00%, 89.32%); opacity: 0.83" title="0.002">k</span><span style="background-color: hsl(120, 100.00%, 89.39%); opacity: 0.83" title="0.002">i</span><span style="background-color: hsl(120, 100.00%, 91.74%); opacity: 0.82" title="0.001">d</span><span style="background-color: hsl(0, 100.00%, 96.60%); opacity: 0.81" title="-0.000">n</span><span style="background-color: hsl(0, 100.00%, 93.50%); opacity: 0.81" title="-0.001">e</span><span style="background-color: hs

# %% [markdown]
# # HashingVectorizer

# %%
twenty_train = fetch_20newsgroups(
    subset='train',
    categories=categories,
    shuffle=True,
    random_state=42,
    remove=['headers', 'footers'],
)
twenty_test = fetch_20newsgroups(
    subset='test',
    categories=categories,
    shuffle=True,
    random_state=42,
    remove=['headers', 'footers'],
)

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import SGDClassifier

vec = HashingVectorizer(stop_words='english', ngram_range=(1,2))
clf = SGDClassifier(random_state=42)
pipe = make_pipeline(vec, clf)
pipe.fit(twenty_train.data, twenty_train.target)

print_report(pipe)
# Out:
#                         precision    recall  f1-score   support
#
#            alt.atheism       0.92      0.79      0.85       319
#          comp.graphics       0.87      0.96      0.92       389
#                sci.med       0.93      0.89      0.91       396
# soc.religion.christian       0.88      0.93      0.91       398
#
#               accuracy                           0.90      1502
#              macro avg       0.90      0.89      0.90      1502
#           weighted avg       0.90      0.90      0.90      1502
#
# accuracy: 0.899

# %%
eli5.show_prediction(clf, twenty_test.data[0], vec=vec,
                     target_names=twenty_test.target_names,)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (score <b>-0.935</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.025
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.960
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as i </span><span style="background-color: hsl(0, 100.00%, 92.17%); opacity: 0.82" title="-0.024">recall</span><span style="opacity: 0.80"> from my </span><span style="background-color: hsl(120, 100.00%, 96.57%); opacity: 0.81" title="0.007">bout</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(0, 100.00%, 94.42%); opacity: 0.81" title="-0.015">kidney</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.68%); opacity: 0.80" title="-0.002">stones</span><span style="opacity: 0.80">, there </span><span style="background-color: hsl(120, 100.00%, 73.60%); opacity: 0.91" title="0.137">isn</span><span style="opacity: 0.80">&#x27;t any
# </span><span style="background-color: hsl(0, 100.00%, 95.78%); opacity: 0.81" title="-0.010">medication</span><span style="opacity: 0.80"> that can do anything about them except relieve the </span><span style="background-color: hsl(0, 100.00%, 88.08%); opacity: 0.84" title="-0.044">pain</span><span style="opacity: 0.80">.
#
# either they </span><span style="background-color: hsl(120, 100.00%, 95.10%); opacity: 0.81" title="0.012">pass</span><span style="opacity: 0.80">, or they have to be </span><span style="background-color: hsl(0, 100.00%, 88.88%); opacity: 0.83" title="-0.040">broken</span><span style="opacity: 0.80"> up with </span><span style="background-color: hsl(0, 100.00%, 93.79%); opacity: 0.81" title="-0.017">sound</span><span style="opacity: 0.80">, or they have
# to be </span><span style="background-color: hsl(0, 100.00%, 94.81%); opacity: 0.81" title="-0.013">extracted</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.33%); opacity: 0.80" title="-0.003">surgically</span><span style="opacity: 0.80">.
#
# when i was in, the x-</span><span style="background-color: hsl(120, 100.00%, 97.97%); opacity: 0.80" title="0.004">ray</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.34%); opacity: 0.83" title="-0.033">tech</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.52%); opacity: 0.81" title="0.014">happened</span><span style="opacity: 0.80"> to </span><span style="background-color: hsl(120, 100.00%, 83.95%); opacity: 0.85" title="0.067">mention</span><span style="opacity: 0.80"> that she&#x27;d had </span><span style="background-color: hsl(0, 100.00%, 94.42%); opacity: 0.81" title="-0.015">kidney</span><span style="opacity: 0.80">
# </span><span style="background-color: hsl(0, 100.00%, 98.68%); opacity: 0.80" title="-0.002">stones</span><span style="opacity: 0.80"> and </span><span style="background-color: hsl(120, 100.00%, 93.07%); opacity: 0.82" title="0.020">children</span><span style="opacity: 0.80">, and the </span><span style="background-color: hsl(0, 100.00%, 97.75%); opacity: 0.80" title="-0.004">childbirth</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.08%); opacity: 0.82" title="-0.029">hurt</span><span style="opacity: 0.80"> less.</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=comp.graphics
#
# </b>
#
#
#     (score <b>-0.705</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 91.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.271
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.435
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as i </span><span style="background-color: hsl(0, 100.00%, 91.13%); opacity: 0.82" title="-0.029">recall</span><span style="opacity: 0.80"> from my </span><span style="background-color: hsl(0, 100.00%, 99.19%); opacity: 0.80" title="-0.001">bout</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(0, 100.00%, 91.52%); opacity: 0.82" title="-0.027">kidney</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.07%); opacity: 0.82" title="-0.025">stones</span><span style="opacity: 0.80">, there </span><span style="background-color: hsl(0, 100.00%, 89.80%); opacity: 0.83" title="-0.035">isn</span><span style="opacity: 0.80">&#x27;t any
# </span><span style="background-color: hsl(0, 100.00%, 86.36%); opacity: 0.84" title="-0.053">medication</span><span style="opacity: 0.80"> that can do anything about them except </span><span style="background-color: hsl(0, 100.00%, 97.64%); opacity: 0.80" title="-0.004">relieve</span><span style="opacity: 0.80"> the </span><span style="

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = [
    'This is the first document.',
    'This document is the second document.',
    '福建春季公务员考试报名18日截止 2月6日考试',
    '意甲首轮补赛交战记录:米兰客场8战不败国米10年连胜',
]
vectorizer = TfidfVectorizer(analyzer='char_wb', ngram_range= (1,6))
X = vectorizer.fit_transform(corpus)
print([(len(w),w) for w in vectorizer.get_feature_names()])
# Out:
# [(1, ' '), (2, ' 2'), (3, ' 2月'), (4, ' 2月6'), (5, ' 2月6日'), (6, ' 2月6日考'), (2, ' d'), (3, ' do'), (4, ' doc'), (5, ' docu'), (6, ' docum'), (2, ' f'), (3, ' fi'), (4, ' fir'), (5, ' firs'), (6, ' first'), (2, ' i'), (3, ' is'), (4, ' is '), (2, ' s'), (3, ' se'), (4, ' sec'), (5, ' seco'), (6, ' secon'), (2, ' t'), (3, ' th'), (4, ' the'), (5, ' the '), (4, ' thi'), (5, ' this'), (6, ' this '), (
6, '公务员考试报'), (1, '兰'), (2, '兰客'), (3, '兰客场'), (4, '兰客场8'), (5, '兰客场8战'), (6, '兰客场8战不'), (1, '务'), (2, '务员'), (3, '务员考'), (4, '务员考试'), (5, '务员考试报'), (6, '务员考试报名'), (1, '名'), (2, '名1'), (3, '名18'), (4, '名18日'), (5, '名18日截'), (6, '名18日截止'), (1, '员'), (2, '员考'), (3, '员考试'), (4, '员考试报'), (5, '员考试报名'), (6, '员考试报名1'), (1, '国'), (2, '国米'), (3, '国米1'), (4, '国米10'), (5, '国米10年'), (6, '国米10年连'), (1, '场'), (2, '场8'), (3, '场8战'), (4, '场8战不'), (5, '场8战不败'), (6, '场8战不败国'), (1, '季'), (2, '季公'), (3, '季公务'), (4, '季公务员'), (5, '季公务员考'), (6, '季公务员考试'), (1, '客'), (2, '客场'), (3, '客场8'), (4, '客场8战'), (5, '客场8战不'), (6, '客场8战不败'), (1, '年'), (2, '年连'), (3, '年连胜'), (4, '年连胜 '), (1, '建'), (2, '建春'), (3, '建春季'), (4, '建春季公'), (5, '建春季公务'), (6, '建春季公务员'), (1, '录'), (2, '录:'), (3, '录:米'), (4, '录:米兰'), (5, '录:米兰客'), (6, '录:米兰客场'), (1, '意'), (2, '意甲'), (3, '意甲首'), (4, '意甲首轮'), (5, '意甲首轮补'), (6, '意甲首轮补赛'), (1, '战'), (2, '战不'), (3, '战不败'), (4, '战不败国'), (5, '战不败国米'), (6, '战不败国米1'), (2, '战记'), (3, '战记录'), (4, '战记录:'), (5, '战记录:米'), (6, '战记录:米兰'), (1, '截'), (2, '截止'), (3, '截止 '), (1, '报'), (2, '报名'), (3, '报名1'), (4, '报名18'), (5, '报名18日'), (6, '报名18日截'), (1, '日'), (2, '日截'), (3, '日截止'), (4, '日截止 '), (2, '日考'), (3, '日考试'), (4, '日考试 '), (1, '春'), (2, '春季'), (3, '春季公'), (4, '春季公务'), (5, '春季公务员'), (6, '春季公务员考'), (1, '月'), (2, '月6'), (3, '月6日'), (4, '月6日考'), (5, '月6日考试'), (6, '月6日考试 '), (1, '止'), (2, '止 '), (1, '甲'), (2, '甲首'), (3, '甲首轮'), (4, '甲首轮补'), (5, '甲首轮补赛'), (6, '甲首轮补赛交'), (1, '福'), ( ...

# %%
from IPython.display import display
display(eli5.show_weights(new_m.model))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sports
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.136
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x35
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.136
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x36
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.136
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x57
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x27
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x16
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x17
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x18
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x19
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x29
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x56
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x55
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x68
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x47
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x28
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x37
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x48
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x39
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x14
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x15
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x0
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 33 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 40 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>

# %%
display(eli5.show_weights(clf2))

# %%
import eli5
eli5.show_weights(m, top=10)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div style="background-color: #fdd; padding: 0.5em;">
#         Error: estimator TextClassifier instance (lr, <__main__.CharTokenizer object at 0x7fccbb6fb310>) is not supported
#     </div>

# %%
eli5.show_weights(new_m, vec = new_m.vectorizer,
                        top=10,
                        target_names = ['education', 'sports'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div style="background-color: #fdd; padding: 0.5em;">
#         Error: estimator TextClassifier instance (lr, <__main__.CharTokenizer object at 0x7fccb765d340>) is not supported
#     </div>
